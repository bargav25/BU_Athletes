# %%
# %run ./dataframe.ipynb
print(df.columns)
# Out:
# 993
# Index(['Data Input Year', 'State', 'Country', 'Language',
#        'IPEDS Race Description', 'Athletic Code', 'Team Gender', 'Team Name',
#        'HYR', 'Entering Term', 'Yr', 'FCLASS', 'RetentionClass', 'ACADINDEX',
#        'SATCFORAI', 'ACTUSE', 'SATCUSE', 'SATVUSE', 'satm', 'satwr', 'HSGPA',
#        'FIRSTCOLLEGE', 'FIRSTMAJOR', 'First Major Name', 'LASTCOLLEGE',
#        'LASTMAJOR', 'Last Major Name', 'Last Cumulative BU GPA',
#        'Cumulative GPA-1st Sem', 'Cumulative GPA-2nd Sem',
#        'Cumulative GPA-3rd Sem', 'Cumulative GPA-4th Sem',
#        'Cumulative GPA-5th Sem', 'Cumulative GPA-6th Sem',
#        'Cumulative GPA-7th Sem', 'Cumulative GPA-8th Sem',
#        'Cumulative GPA-9th Sem', 'Cumulative GPA-10th Sem',
#        'Cumulative GPA-11th Sem', 'Cumulative GPA-12th Sem',
#        'Cumulative GPA-13th Sem', 'Cumulative GPA-14th Sem',
#        'Cumulative GPA-15th Sem', 'Cumulative GPA-16th Sem',
# ...

# %%
WB_HSGPA, WB_SAT, WB_ACAD = [], [], []
CW_HSGPA, CW_SAT, CW_ACAD = [], [], []
WH_HSGPA, WH_SAT, WH_ACAD = [], [], []
LW_HSGPA, LW_SAT, LW_ACAD = [], [], []
WC_HSGPA, WC_SAT, WC_ACAD = [], [], []
WS_HSGPA, WS_SAT, WS_ACAD = [], [], []
SG_HSGPA, SG_SAT, SG_ACAD = [], [], []
TW_HSGPA, TW_SAT, TW_ACAD = [], [], []
WT_HSGPA, WT_SAT, WT_ACAD = [], [], []
MB_HSGPA, MB_SAT, MB_ACAD = [], [], []
CC_HSGPA, CC_SAT, CC_ACAD = [], [], []
HC_HSGPA, HC_SAT, HC_ACAD = [], [], []
LM_HSGPA, LM_SAT, LM_ACAD = [], [], []
MC_HSGPA, MC_SAT, MC_ACAD = [], [], []
SC_HSGPA, SC_SAT, SC_ACAD = [], [], []
SM_HSGPA, SM_SAT, SM_ACAD = [], [], []
MT_HSGPA, MT_SAT, MT_ACAD = [], [], []
TR_HSGPA, TR_SAT, TR_ACAD = [], [], []

for i, row in df.iterrows():
    if row['Athletic Code'] == 'WB':
        if row['HSGPA'] is not None:
            WB_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            WB_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            WB_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'CW':
        if row['HSGPA'] is not None:
            CW_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            CW_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            CW_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'WH':
        if row['HSGPA'] is not None:
            WH_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            WH_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            WH_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'LW':
        if row['HSGPA'] is not None:
            LW_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            LW_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            LW_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'WC':
        if row['HSGPA'] is not None:
            WC_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            WC_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            WC_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'WS':
        if row['HSGPA'] is not None:
            WS_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            WS_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            WS_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'SG':
        if row['HSGPA'] is not None:
            SG_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            SG_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            SG_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'TW':
        if row['HSGPA'] is not None:
            TW_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            TW_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            TW_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'WT':
        if row['HSGPA'] is not None:
            WT_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            WT_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            WT_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'MB':
        if row['HSGPA'] is not None:
            MB_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            MB_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            MB_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'CC':
        if row['HSGPA'] is not None:
            CC_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            CC_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            CC_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'HC':
        if row['HSGPA'] is not None:
            HC_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            HC_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            HC_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'LM':
        if row['HSGPA'] is not None:
            LM_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            LM_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            LM_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'MC':
        if row['HSGPA'] is not None:
            MC_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            MC_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            MC_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'SC':
        if row['HSGPA'] is not None:
            SC_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            SC_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            SC_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'SM':
        if row['HSGPA'] is not None:
            SM_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            SM_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            SM_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'MT':
        if row['HSGPA'] is not None:
            MT_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            MT_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            MT_ACAD.append(row['ACADINDEX'])
    elif row['Athletic Code'] == 'TR':
        if row['HSGPA'] is not None:
            TR_HSGPA.append(row['HSGPA'])
        if row['SATCFORAI'] is not None:
            TR_SAT.append(row['SATCFORAI'])
        if row['ACADINDEX'] is not None:
            TR_ACAD.append(row['ACADINDEX'])

# %%
print(WB_HSGPA)
# Out:
# [3.2, 3.1, 3.5, 3.7, 3.8, 2.8, 2.8, 4.0, 4.0, 3.2, 3.4, 4.0, 3.8, 3.9, 3.8, 4.0, 3.5, 3.5, 3.7, 4.0, 4.0]

# %%
import numpy as np
import matplotlib.pyplot as plt
WB_HSGPA = [x for x in WB_HSGPA if not np.isnan(x)]
WB_SAT = [x for x in WB_SAT if not np.isnan(x)]
WB_ACAD = [x for x in WB_ACAD if not np.isnan(x)]

MB_HSGPA = [x for x in MB_HSGPA if not np.isnan(x)]
MB_SAT = [x for x in MB_SAT if not np.isnan(x)]
MB_ACAD = [x for x in MB_ACAD if not np.isnan(x)]

CC_HSGPA = [x for x in CC_HSGPA if not np.isnan(x)]
CC_SAT = [x for x in CC_SAT if not np.isnan(x)]
CC_ACAD = [x for x in CC_ACAD if not np.isnan(x)]

CW_HSGPA = [x for x in CW_HSGPA if not np.isnan(x)]
CW_SAT = [x for x in CW_SAT if not np.isnan(x)]
CW_ACAD = [x for x in CW_ACAD if not np.isnan(x)]

HC_HSGPA = [x for x in HC_HSGPA if not np.isnan(x)]
HC_SAT = [x for x in HC_SAT if not np.isnan(x)]
HC_ACAD = [x for x in HC_ACAD if not np.isnan(x)]

WH_HSGPA = [x for x in WH_HSGPA if not np.isnan(x)]
WH_SAT = [x for x in WH_SAT if not np.isnan(x)]
WH_ACAD = [x for x in WH_ACAD if not np.isnan(x)]

LM_HSGPA = [x for x in LM_HSGPA if not np.isnan(x)]
LM_SAT = [x for x in LM_SAT if not np.isnan(x)]
LM_ACAD = [x for x in LM_ACAD if not np.isnan(x)]

LW_HSGPA = [x for x in LW_HSGPA if not np.isnan(x)]
LW_SAT = [x for x in LW_SAT if not np.isnan(x)]
LW_ACAD = [x for x in LW_ACAD if not np.isnan(x)]

MC_HSGPA = [x for x in MC_HSGPA if not np.isnan(x)]
MC_SAT = [x for x in MC_SAT if not np.isnan(x)]
MC_ACAD = [x for x in MC_ACAD if not np.isnan(x)]

WC_HSGPA = [x for x in WC_HSGPA if not np.isnan(x)]
WC_SAT = [x for x in WC_SAT if not np.isnan(x)]
WC_ACAD = [x for x in WC_ACAD if not np.isnan(x)]

SC_HSGPA = [x for x in SC_HSGPA if not np.isnan(x)]
SC_SAT = [x for x in SC_SAT if not np.isnan(x)]
SC_ACAD = [x for x in SC_ACAD if not np.isnan(x)]

WS_HSGPA = [x for x in WS_HSGPA if not np.isnan(x)]
WS_SAT = [x for x in WS_SAT if not np.isnan(x)]
WS_ACAD = [x for x in WS_ACAD if not np.isnan(x)]

SM_HSGPA = [x for x in SM_HSGPA if not np.isnan(x)]
SM_SAT = [x for x in SM_SAT if not np.isnan(x)]
SM_ACAD = [x for x in SM_ACAD if not np.isnan(x)]

SG_HSGPA = [x for x in SG_HSGPA if not np.isnan(x)]
SG_SAT = [x for x in SG_SAT if not np.isnan(x)]
SG_ACAD = [x for x in SG_ACAD if not np.isnan(x)]

MT_HSGPA = [x for x in MT_HSGPA if not np.isnan(x)]
MT_SAT = [x for x in MT_SAT if not np.isnan(x)]
MT_ACAD = [x for x in MT_ACAD if not np.isnan(x)]

TW_HSGPA = [x for x in TW_HSGPA if not np.isnan(x)]
TW_SAT = [x for x in TW_SAT if not np.isnan(x)]
TW_ACAD = [x for x in TW_ACAD if not np.isnan(x)]

TR_HSGPA = [x for x in TR_HSGPA if not np.isnan(x)]
TR_SAT = [x for x in TR_SAT if not np.isnan(x)]
TR_ACAD = [x for x in TR_ACAD if not np.isnan(x)]

WT_HSGPA = [x for x in WT_HSGPA if not np.isnan(x)]
WT_SAT = [x for x in WT_SAT if not np.isnan(x)]
WT_ACAD = [x for x in WT_ACAD if not np.isnan(x)]

# Plotting boxplots
data_to_plot = [WB_HSGPA, MB_HSGPA], [WB_SAT, MB_SAT], [WB_ACAD, MB_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Basketball')

plt.tight_layout()
plt.show()

# Boxplot for CC and CW
data_to_plot = [CW_HSGPA, CC_HSGPA], [CW_SAT, CC_SAT], [CW_ACAD, CC_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Cross Country')

plt.tight_layout()
plt.show()

# Boxplot for HC and WH
data_to_plot = [WH_HSGPA, HC_HSGPA], [WH_SAT, HC_SAT], [WH_ACAD, MC_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Hockey')

plt.tight_layout()
plt.show()

# Boxplot for LM and LW
data_to_plot = [LW_HSGPA, LM_HSGPA], [LW_SAT, LM_SAT], [LW_ACAD, LM_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['M', 'W'])
    ax.set_title(f'Boxplot of {labels[i]} for Lacrosse')

plt.tight_layout()
plt.show()

# Boxplot for MC and WC
data_to_plot = [WC_HSGPA, MC_HSGPA], [WC_SAT, MC_SAT], [WC_ACAD, MC_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Crew')

plt.tight_layout()
plt.show()

# Boxplot for SC and WS
data_to_plot = [WS_HSGPA, SC_HSGPA], [WS_SAT, SC_SAT], [WS_ACAD, SC_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Soccer')

plt.tight_layout()
plt.show()

# Boxplot for SM and SQ
data_to_plot = [SG_HSGPA, SM_HSGPA], [SG_SAT, SM_SAT], [SG_ACAD, SM_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Swimming')

plt.tight_layout()
plt.show()

# Boxplot for MT and TW
data_to_plot = [TW_HSGPA, MT_HSGPA], [TW_SAT, MT_SAT], [TW_ACAD, MT_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Tennis')

plt.tight_layout()
plt.show()

# Boxplot for TR and WT
data_to_plot = [WT_HSGPA, TR_HSGPA], [WT_SAT, TR_SAT], [WT_ACAD, TR_ACAD]
labels = ['HSGPA', 'SAT', 'ACADINDEX']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

for i, ax in enumerate(axes):
    ax.boxplot(data_to_plot[i])
    ax.set_xticklabels(['W', 'M'])
    ax.set_title(f'Boxplot of {labels[i]} for Track and Field')

plt.tight_layout()
plt.show()
